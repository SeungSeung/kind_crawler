# %%
import selenium
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
import numpy as np
import datetime
import time
import os
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import asyncio
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import requests
from urllib import request
from urllib.error import HTTPError
from urllib.error import URLError

today=datetime.datetime.today()
yesterday=today-datetime.timedelta(1)
today=str(pd.to_datetime(today))[:10]
yesterday=str(pd.to_datetime(yesterday))[:10]




files=os.listdir()

# %% [markdown]
# ### 코스피 크롤링

# %%
url='http://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain'
path=os.getcwd()
driver=webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
time.sleep(2)



# url='http://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain'
# path=os.getcwd()
# driver=webdriver.Chrome(ChromeDriverManager().install())
# driver.get(url)
# time.sleep(2)
####공시 100 페이지로 늘리기
#driver.find_element(By.XPATH,'//*[@id="currentPageSize"]').click()
driver.find_element(By.XPATH,'//*[@id="currentPageSize"]/option[4]').click()
driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[2]/a').click()


driver.find_element(By.XPATH,'//*[@id="search-btn-dates"]/ul/li[7]/a').click()

driver.find_element(By.XPATH,'//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click()
time.sleep(7)
driver.find_element(By.XPATH,'//*[@id="rWertpapier"]').click()###유가증권 여부
time.sleep(5)
driver.find_element(By.XPATH,'//*[@id="dsclsType01"]').click()###수시공시 클릭
driver.find_element(By.XPATH,'//*[@id="dsclsLayer01_26"]').click()### 시설투자 클릭
driver.find_element(By.XPATH,'//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click()## 검색 클릭
time.sleep(2)




###총 몇페이지인지
last_page=np.ceil(int(driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[2]/em').text)/100)
infra_dict=dict()
while True:
    
    ####현재 몇페이지 인지
    now_page=int(driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[2]/strong').text)
    
    
    ####현 페이지에서 제일 큰 공시번호 
    num=driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[1]/table/tbody/tr[1]/td[1]').text
    num=int(num)
    X_path_list=[]####공시 제목 XPATH
    #infra_dict=dict()
    company_name_data=driver.find_elements(By.XPATH,f'//*[@id="companysum"]')
    
    
    if now_page<last_page:
        spread=100
    elif now_page==last_page:
        spread=int(driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[2]/em').text)%100
    
    time.sleep(2)
    for i in range(1,spread+1):
        X_path_list.append(f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[4]/a')
        date=driver.find_element(By.XPATH,f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[2]').text
        date=date[:10]
        #time.sleep(1)
        temp_company_name=company_name_data[i-1].text
        report_code=driver.find_element(By.XPATH,X_path_list[i-1]).get_attribute("onclick")#### 공시레포트 코드 가져오기
        c_index = report_code.find("(") # 키 값 파싱
        ind_code_r = report_code[(c_index+2):(c_index+2+14)]
        temp_tag=driver.find_element(By.XPATH,f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[4]/a').text
        infra_dict[ind_code_r]=(date,temp_tag+temp_company_name)
    
    #driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[1]/a[12]').click()
    
    
    driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[1]/a[6]').click()
    time.sleep(2)
    if now_page==last_page: break
    
        
if '시설외'  not in temp_tag: 
    convert_infra_dict={v:k for k,v in infra_dict.items()}
    flag_list=[ flag for flag in infra_dict.values() if '정정' in flag[1]]
    infra_dict2=infra_dict.copy()
    for temp_infra in infra_dict.values():
        for infra_two in flag_list:
            
            if (temp_infra[1] in infra_two[1]) and ('정정' not in temp_infra[1]):
                #print(temp_infra[1])
                try:
                    infra_dict2.pop(convert_infra_dict[temp_infra])
                except Exception as e:
                    print(e)    
                
                
                
df=pd.DataFrame(columns=['code','name','announce_date','total_ratio'])
tickers=list()
announce_date=list()
name=list()
ratio_list=list()
# Out:
# [WDM] - Downloading: 100%|████████████████████████████████████████████████████████| 6.58M/6.58M [00:00<00:00, 22.7MB/s]
# C:\Users\exp202207\AppData\Local\Temp\ipykernel_3080\2700242127.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install())
# '20220727000435'
# '20220727000435'
# '20220720000360'
# '20220620000628'
# '20220620000628'
# '20220620000628'
# '20220527000171'
# '20220527000171'
# '20211213000200'
# '20211213000200'
# '20211111000401'
# '20211111000382'
# '20210719000110'
# '20210708000165'
# '20210707000114'
# '20210707000108'
# '20210629000367'
# '20210629000367'
# '20210629000367'
# '20210622000329'
# '20210407000275'
# '20210407000275'
# '20210216000763'
# '20210216000763'
# '20210216000763'
# '20210209000893'
# '20210209000893'
# '20210209000893'
# '20210125000670'
# '20201231000176'
# '20201231000176'
# '20201228000136'
# '20201222000531'
# '20201222000531'
# '20201111000461'
# '20201111000461'
# '20201111000461'
# '20201106000387'
# '20201106000387'
# '20201019000179'
# '20201019000179'
# '20201005000497'
# '20200928000427'
# '20200825000426'
# '20200812000459'
# '20200812000459'
# '20200812000459'
# '20200805000107'
# '20200805000107'
# '20200630000199'
# '20200527000425'
# '20200417000571'
# '20200417000571'
# '20200417000571'
# '20200330002007'
# '20200330002007'
# '20200221001007'

# %%
# Out:
# Empty DataFrame
# Columns: [code, name, announce_date, total_ratio]
# Index: []

# %%
df=pd.DataFrame(columns=['code','name','announce_date','total_ratio'])
tickers=list()
announce_date=list()
name=list()
ratio_list=list()       
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/101.0.4951.54 Safari/537.36',
        "Accept-Language":'ko-KR,ko'}
if len(infra_dict2.keys()) !=0:
    for report_code in infra_dict2.keys():
        #if '정정' in reassess_dict[report_code][1]: 
        if '시설외' not in  infra_dict2[report_code][1] and '자회사' not in  infra_dict2[report_code][1]:
        
        
            announce_date.append(infra_dict2[report_code][0])
            new_url_temp= "https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno=" + report_code + "&docno=&viewerhost=&viewerport#viewer"
            res=request.urlopen(new_url_temp)
            soup = BeautifulSoup(res, "lxml")
            
            
            nth_options=str(soup.select('#mainDoc')[0]).count('</option>')
            tag1 = soup.select(f'#mainDoc > option:nth-of-type({nth_options})')
            code_name=soup.find('h1',attrs={'class':'ttl type-99 fleft'}).text ###이름 하고 기업 코드 추출
            
            company_name,company_code=code_name.split(' ')
            name.append(company_name)
            company_code=company_code[1:-1]
            company_code='A'+company_code
            tickers.append(company_code)

            x = tag1[0]
            key_text = x.get("value")
            key_report_dir = key_text[0:14]
            #print(key_report_dir)
            new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/31155.htm'
            
            
            try:
                res=request.urlopen(new_url)
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
            time.sleep(0.05)
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/71361.htm'
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
            time.sleep(0.05)
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/61361.htm'
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
            time.sleep(0.05)
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/99111.htm'
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
                
                
                
                
                
     
                
            # soup=BeautifulSoup(res,'lxml')
            # temps_ratio=soup.select_one('#XFormD1_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span').text
            # if len(temps_ratio)<6:
            #     ratio=float(temps_ratio)
            # else:
            #     temps_ratio=soup.select_one(' #XFormD1_Form0_Table0 > tbody > tr:nth-child(5) > td:nth-child(2) > span').text
            #     ratio=float(temps_ratio)
            
            
            for i in range(len(df)):
                temp_df=df[i]
                if len(temp_df)>3:
                    temp_df=temp_df.set_index(1)
                    if '자기자본대비(%)' in temp_df.index:
                        ratio=temp_df.loc['자기자본대비(%)',2]
                        ratio=ratio.replace('-','0')
                        ratio_list.append(float(ratio))
                    
                
                
            
            # if len(df)>1:
            #     ratio=float(df[1].loc[4,2])
                
            # else:
            #     ratio=float(df[0].loc[4,2])
            # ratio_list.append(ratio)
            
            
data={'code':tickers,'name':name,'announce_date':announce_date,
        'ratio':ratio_list}
new_df=pd.DataFrame(data,columns=['code','name','announce_date','ratio'])
        
new_df=new_df.set_index('code')
# Out:
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found

# %%
new_df
# Out:
#            name announce_date  ratio
# code
# A005420   코스모화학    2023-01-02   5.25
# A014680   한솔케미칼    2022-12-30  13.66
# A003720  삼영화학공업    2022-12-30  59.02
# A000180  성창기업지주    2022-12-29  27.20
# A034300   신세계건설    2022-12-19  37.59
# ...         ...           ...    ...
# A003550      LG    2020-02-03   1.57
# A051910    LG화학    2020-02-03   1.57
# A002320      한진    2020-01-21  26.71
# A028670     팬오션    2020-01-16   5.92
# A044450   KSS해운    2020-01-07  35.64
#
# [219 rows x 3 columns]

# %%
kospi_infra=pd.read_csv('kospi_infra_invest_ratio.csv',index_col=0)
df=pd.concat([kospi_infra,new_df])
df=df.drop_duplicates()

# %%
df
# Out:
#            name announce_date  ratio
# code
# A005420   코스모화학    2023-01-02   5.25
# A014680   한솔케미칼    2022-12-30  13.66
# A003720  삼영화학공업    2022-12-30  59.02
# A000180  성창기업지주    2022-12-29  27.20
# A034300   신세계건설    2022-12-19  37.59
# ...         ...           ...    ...
# A225430   케이엠제약    2020-01-30  10.07
# A052900   KX하이텍    2020-01-28  11.95
# A089530  에이티세미콘    2020-01-23  11.95
# A259630    엠플러스    2020-01-22  27.12
# A003380    하림지주    2020-01-16   5.92
#
# [598 rows x 3 columns]

# %%
kospi_original=pd.read_csv('data\kospi_infra_invest_ratio.csv',index_col=0)
kosdaq_original=pd.read_csv('data\kosdaq_infra_invest_ratio.csv',index_col=0)
df_original=pd.concat([kospi_original,kosdaq_original])
df_original=df_original.drop_duplicates()
df_original
# Out:
#             name announce_date  ratio
# code
# A034300    신세계건설    2022-12-19  37.59
# A018670     SK가스    2022-12-15  11.50
# A339770   교촌에프앤비    2022-12-02  15.50
# A229640  LS전선아시아    2022-11-30  11.28
# A003670   포스코케미칼    2022-11-30  34.40
# ...          ...           ...    ...
# A036810    에프에스티    2019-12-31  23.20
# A290670   대보마그네틱    2019-12-30  23.20
# A220100      퓨쳐켐    2019-12-30  54.11
# A003100       선광    2019-12-26  54.11
# A140070  서플러스글로벌    2019-12-26  54.11
#
# [601 rows x 3 columns]

# %%
infra_df=pd.concat([df_original,df])
infra_df=infra_df.drop_duplicates()
infra_df
# Out:
#             name announce_date   ratio
# code
# A034300    신세계건설    2022-12-19   37.59
# A018670     SK가스    2022-12-15   11.50
# A339770   교촌에프앤비    2022-12-02   15.50
# A229640  LS전선아시아    2022-11-30   11.28
# A003670   포스코케미칼    2022-11-30   34.40
# ...          ...           ...     ...
# A269620      시스웍    2022-04-29    0.00
# A247660   나노씨엠에스    2022-04-29    0.00
# A302550      리메드    2022-04-28    0.00
# A352700     씨앤투스    2021-04-20  103.44
# A247660   나노씨엠에스    2021-04-15  103.44
#
# [624 rows x 3 columns]

# %%
infra_df.to_csv('infra_data.csv')

# %%
data={'code':tickers,'name':name,'announce_date':announce_date,
        'ratio':ratio_list}
new_df=pd.DataFrame(data,columns=['code','name','announce_date','ratio'])
        
new_df=new_df.set_index('code')

# %%
new_df.to_csv('kospi_infra_invest_ratio.csv')

# %% [markdown]
# #### 코스닥 크롤링

# %%
url='http://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain'
path=os.getcwd()
driver=webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
time.sleep(2)



# url='http://kind.krx.co.kr/disclosure/details.do?method=searchDetailsMain'
# path=os.getcwd()
# driver=webdriver.Chrome(ChromeDriverManager().install())
# driver.get(url)
# time.sleep(2)
####공시 100 페이지로 늘리기
#driver.find_element(By.XPATH,'//*[@id="currentPageSize"]').click()
driver.find_element(By.XPATH,'//*[@id="currentPageSize"]/option[4]').click()
driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[2]/a').click()


driver.find_element(By.XPATH,'//*[@id="search-btn-dates"]/ul/li[7]/a').click()

driver.find_element(By.XPATH,'//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click()
time.sleep(7)

driver.find_element(By.XPATH,'//*[@id="rKosdaq"]').click()###코스닥 여부
time.sleep(5)
driver.find_element(By.XPATH,'//*[@id="dsclsType01"]').click()###수시공시 클릭
driver.find_element(By.XPATH,'//*[@id="dsclsLayer01_26"]').click()### 시설투자 클릭
driver.find_element(By.XPATH,'//*[@id="searchForm"]/section[1]/div/div[3]/a[1]').click()## 검색 클릭
time.sleep(2)




###총 몇페이지인지
last_page=np.ceil(int(driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[2]/em').text)/100)
infra_dict=dict()
while True:
    
    ####현재 몇페이지 인지
    now_page=int(driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[2]/strong').text)
    
    
    ####현 페이지에서 제일 큰 공시번호 
    num=driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[1]/table/tbody/tr[1]/td[1]').text
    num=int(num)
    X_path_list=[]####공시 제목 XPATH
    #infra_dict=dict()
    company_name_data=driver.find_elements(By.XPATH,f'//*[@id="companysum"]')
    
    
    if now_page<last_page:
        spread=100
    elif now_page==last_page:
        spread=int(driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[2]/em').text)%100
    
    time.sleep(2)
    for i in range(1,spread+1):
        X_path_list.append(f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[4]/a')
        date=driver.find_element(By.XPATH,f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[2]').text
        date=date[:10]
        #time.sleep(1)
        temp_company_name=company_name_data[i-1].text
        report_code=driver.find_element(By.XPATH,X_path_list[i-1]).get_attribute("onclick")#### 공시레포트 코드 가져오기
        c_index = report_code.find("(") # 키 값 파싱
        ind_code_r = report_code[(c_index+2):(c_index+2+14)]
        temp_tag=driver.find_element(By.XPATH,f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[4]/a').text
        infra_dict[ind_code_r]=(date,temp_tag+temp_company_name)
    
    #driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[1]/a[12]').click()
    
   
    driver.find_element(By.XPATH,'//*[@id="main-contents"]/section[2]/div[1]/a[9]').click()
    time.sleep(2)
    if now_page==last_page: break
    
        
if '시설외'  not in temp_tag: 
    convert_infra_dict={v:k for k,v in infra_dict.items()}
    flag_list=[ flag for flag in infra_dict.values() if '정정' in flag[1]]
    infra_dict2=infra_dict.copy()
    for temp_infra in infra_dict.values():
        for infra_two in flag_list:
            
            if (temp_infra[1] in infra_two[1]) and ('정정' not in temp_infra[1]):
                #print(temp_infra[1])
                try:
                    infra_dict2.pop(convert_infra_dict[temp_infra])
                except Exception as e:
                    print(e)    
                
                
                
df=pd.DataFrame(columns=['code','name','announce_date','total_ratio'])
tickers=list()
announce_date=list()
name=list()
ratio_list=list()
# Out:
# C:\Users\exp202207\AppData\Local\Temp\ipykernel_3080\4236694921.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(ChromeDriverManager().install())
# '20230105000185'
# '20221226000585'
# '20221226000585'
# '20221026000216'
# '20221026000216'
# '20220822000118'
# '20220822000118'
# '20220812000268'
# '20220808000189'
# '20220808000189'
# '20220628000701'
# '20220628000701'
# '20220628000701'
# '20220628000701'
# '20220420000256'
# '20220408000190'
# '20220304000476'
# '20220303000275'
# '20220302000566'
# '20220128000448'
# '20220128000448'
# '20220127000170'
# '20220124000485'
# '20211207000278'
# '20211207000278'
# '20211119000176'
# '20211111000416'
# '20211111000416'
# '20211105000676'
# '20211105000676'
# '20211014000113'
# '20211014000113'
# '20211005000303'
# '20211001000321'
# '20210910000149'
# '20210823000087'
# '20210823000087'
# '20210818000154'
# '20210616000329'
# '20210616000329'
# '20210601000109'
# '20210514000135'
# '20210514000135'
# '20210507000721'
# '20210507000721'
# '20210507000721'
# '20210507000721'
# '20210506000191'
# '20210506000191'
# '20210412000687'
# '20210405000405'
# '20210402000533'
# '20210402000533'
# '20210402000533'
# '20210322000459'
# '20210322000459'
# '20210311001033'
# '20210311001033'
# '20210311001033'
# '20210309000801'
# '20210304000701'
# '20210304000701'
# '20210304000701'
# '20210303000436'
# '20210303000436'
# '20210302000955'
# '20210302000955'
# '20210224000945'
# '20210224000945'
# '20210224000945'
# '20210224000945'
# '20210224000428'
# '20210224000428'
# '20210215000438'
# '20210202000565'
# '20210202000565'
# '20210126000152'
# '20210107000155'
# '20210107000155'
# '20210104000320'
# '20201218000359'
# '20201218000359'
# '20201218000359'
# '20201203000191'
# '20201202000329'
# '20201130000322'
# '20201130000322'
# '20201126000456'
# '20201126000456'
# '20201126000456'
# '20201126000456'
# '20201126000452'
# '20201126000452'
# '20201113000545'
# '20201113000545'
# '20201019000302'
# '20201015000200'
# '20201015000200'
# '20201015000200'
# '20201015000200'
# '20201014000172'
# '20201014000172'
# '20200925000663'
# '20200925000172'
# '20200925000172'
# '20200819000159'
# '20200716000205'
# '20200716000205'
# '20200713000144'
# '20200612000178'
# '20200401000537'
# '20200401000537'
# '20200401000537'
# '20200227000683'
# '20200224000477'
# '20200206000616'
# '20200205000759'
# '20200205000759'
# '20200204000563'
# '20200204000563'
# '20200204000563'
# '20200204000563'

# %%
df=pd.DataFrame(columns=['code','name','announce_date','total_ratio'])
tickers=list()
announce_date=list()
name=list()
ratio_list=list()       
if len(infra_dict2.keys()) !=0:
    for report_code in infra_dict2.keys():
        #if '정정' in reassess_dict[report_code][1]: 
        if '시설외' not in  infra_dict2[report_code][1]:
        
        
            announce_date.append(infra_dict2[report_code][0])
            new_url_temp= "https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno=" + report_code + "&docno=&viewerhost=&viewerport#viewer"
            res=request.urlopen(new_url_temp)
            soup = BeautifulSoup(res, "lxml")
            
            
            nth_options=str(soup.select('#mainDoc')[0]).count('</option>')
            tag1 = soup.select(f'#mainDoc > option:nth-of-type({nth_options})')
            code_name=soup.find('h1',attrs={'class':'ttl type-99 fleft'}).text ###이름 하고 기업 코드 추출
            
            company_name,company_code=code_name.split(' ')
            name.append(company_name)
            company_code=company_code[1:-1]
            company_code='A'+company_code
            tickers.append(company_code)

            x = tag1[0]
            key_text = x.get("value")
            key_report_dir = key_text[0:14]
            #print(key_report_dir)
            new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/31155.htm'
            
            
            try:
                res=request.urlopen(new_url)
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/71361.htm'
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/61361.htm'
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/99111.htm'
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
                
                
                
                
                
     
                
            # soup=BeautifulSoup(res,'lxml')
            # temps_ratio=soup.select_one('#XFormD1_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span').text
            # if len(temps_ratio)<6:
            #     ratio=float(temps_ratio)
            # else:
            #     temps_ratio=soup.select_one(' #XFormD1_Form0_Table0 > tbody > tr:nth-child(5) > td:nth-child(2) > span').text
            #     ratio=float(temps_ratio)
            
            
            for i in range(len(df)):
                temp_df=df[i]
                if len(temp_df)>3:
                    temp_df=temp_df.set_index(1)
                    if '자기자본대비(%)' in temp_df.index:
                        ratio=temp_df.loc['자기자본대비(%)',2]
                        ratio=ratio.replace('-','0')
                        ratio_list.append(float(ratio))
                    
                
                
            
            # if len(df)>1:
            #     ratio=float(df[1].loc[4,2])
                
            # else:
            #     ratio=float(df[0].loc[4,2])
            # ratio_list.append(ratio)
            
            
data={'code':tickers,'name':name,'announce_date':announce_date,
        'ratio':ratio_list}
new_df=pd.DataFrame(data,columns=['code','name','announce_date','ratio'])
        
new_df=new_df.set_index('code')
# Out:
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found

# %%
data={'code':tickers,'name':name,'announce_date':announce_date,
        'ratio':ratio_list}
new_df=pd.DataFrame(data,columns=['code','name','announce_date','ratio'])
        
new_df=new_df.set_index('code')
new_df.to_csv('kosdaq_infra_invest_ratio.csv')

# %%
new_df
# Out:
#            name announce_date  ratio
# code
# A078600  대주전자재료    2023-01-02  43.13
# A269620     시스웍    2022-12-30  18.38
# A317330  덕산테코피아    2022-12-30  31.64
# A009520   포스코엠텍    2022-12-29   0.00
# A396300  세아메카닉스    2022-12-28  53.80
# ...         ...           ...    ...
# A225430   케이엠제약    2020-01-30  10.07
# A052900   KX하이텍    2020-01-28  11.95
# A089530  에이티세미콘    2020-01-23  11.95
# A259630    엠플러스    2020-01-22  27.12
# A003380    하림지주    2020-01-16   5.92
#
# [387 rows x 3 columns]

# %%
df=pd.DataFrame(columns=['code','name','announce_date','total_ratio'])
tickers=list()
announce_date=list()
name=list()
ratio_list=list()       
if len(infra_dict2.keys()) !=0:
    for report_code in infra_dict2.keys():
        #if '정정' in reassess_dict[report_code][1]: 
        if '시설외' not in  infra_dict2[report_code][1]:
        
        
            announce_date.append(infra_dict2[report_code][0])
            new_url_temp= "https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno=" + report_code + "&docno=&viewerhost=&viewerport#viewer"
            res=request.urlopen(new_url_temp)
            soup = BeautifulSoup(res, "lxml")
            
            
            nth_options=str(soup.select('#mainDoc')[0]).count('</option>')
            tag1 = soup.select(f'#mainDoc > option:nth-of-type({nth_options})')
            code_name=soup.find('h1',attrs={'class':'ttl type-99 fleft'}).text ###이름 하고 기업 코드 추출
            
            company_name,company_code=code_name.split(' ')
            name.append(company_name)
            company_code=company_code[1:-1]
            company_code='A'+company_code
            tickers.append(company_code)

            x = tag1[0]
            key_text = x.get("value")
            key_report_dir = key_text[0:14]
            #print(key_report_dir)
            new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/31155.htm'
            
            
            try:
                res=request.urlopen(new_url)
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/71361.htm'
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/61361.htm'
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/99111.htm'
                df=pd.read_html(new_url)
            except HTTPError as e:
                print(e)
                
                
                
                
                
                
     
                
            # soup=BeautifulSoup(res,'lxml')
            # temps_ratio=soup.select_one('#XFormD1_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span').text
            # if len(temps_ratio)<6:
            #     ratio=float(temps_ratio)
            # else:
            #     temps_ratio=soup.select_one(' #XFormD1_Form0_Table0 > tbody > tr:nth-child(5) > td:nth-child(2) > span').text
            #     ratio=float(temps_ratio)
            
            
            for i in range(len(df)):
                temp_df=df[i]
                if len(temp_df)>3:
                    temp_df=temp_df.set_index(1)
                    if '자기자본대비(%)' in temp_df.index:
                        ratio=temp_df.loc['자기자본대비(%)',2]
                        ratio=ratio.replace('-','0')
                        ratio_list.append(float(ratio))
                    
                
                
            
            # if len(df)>1:
            #     ratio=float(df[1].loc[4,2])
                
            # else:
            #     ratio=float(df[0].loc[4,2])
            # ratio_list.append(ratio)
            
            
data={'code':tickers,'name':name,'announce_date':announce_date,
        'ratio':ratio_list}
new_df=pd.DataFrame(data,columns=['code','name','announce_date','ratio'])
        
new_df=new_df.set_index('code')

# %%
temp=df[3]
temp=temp.set_index(1)
temp.loc['자기자본대비(%)',2]
# Out:
# '15.5'

# %%
len(df[2])
# Out:
# 1

# %%
company_name
# Out:
# '교촌에프앤비'

# %%
company_name
# Out:
# '교촌에프앤비'

# %%
new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/61361.htm'
res=request.urlopen(new_url)

# %%
df_temp=pd.read_html(new_url)
df_temp[1]
# Out:
#                       0                                     1  \
# 0          1. 정정관련 공시서류                             신규 시설투자 등
# 1       2. 정정관련 공시서류제출일                            2021-06-14
# 2               3. 정정사유  대외환경 변화(공사비 증액 등)에 따른 투자금액 및 투자기간 변경
# 3               4. 정정사항                               4. 정정사항
# 4                  정정항목                                   정정전
# 5       2. 투자내역_투자금액(원)                           21720000000
# 6     2. 투자내역_자기자본대비(%)                                  14.1
# 7           4. 투자기간_종료일                            2023-05-31
# 8        5. 이사회결의일(결정일)                            2021-06-14
# 9  7. 기타 투자판단과 관련한 중요사항                                     -
#
#                                              2
# 0                                    신규 시설투자 등
# 1                                   2021-06-14
# 2         대외환경 변화(공사비 증액 등)에 따른 투자금액 및 투자기간 변경
# 3                                      4. 정정사항
# 4                                          정정후
# 5                                  23720000000
# 6                                         15.5
# 7                                   2023-07-31
# 8                                   2022-12-02
# 9  6. 투자내용 변경에 따른 정정 이사회결의일은 2022년 12월 2일 입니다.

# %%
df=pd.read_html(new_url)[0]
df.loc[4,2]
# Out:
# '0.90'

# %%
company_name
# Out:
# '신세계건설'

# %%
df=pd.DataFrame(columns=['code','name','announce_date','total_ratio'])
tickers=list()
announce_date=list()
name=list()
ratio_list=list()       
if len(infra_dict2.keys()) !=0:
    for report_code in infra_dict2.keys():
        #if '정정' in reassess_dict[report_code][1]: 
        if '시설외' not in  infra_dict2[report_code][1]:
        
        
            announce_date.append(infra_dict2[report_code][0])
            new_url_temp= "https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno=" + report_code + "&docno=&viewerhost=&viewerport#viewer"
            res=request.urlopen(new_url_temp)
            soup = BeautifulSoup(res, "lxml")
            
            
            nth_options=str(soup.select('#mainDoc')[0]).count('</option>')
            tag1 = soup.select(f'#mainDoc > option:nth-of-type({nth_options})')
            code_name=soup.find('h1',attrs={'class':'ttl type-99 fleft'}).text ###이름 하고 기업 코드 추출
            
            company_name,company_code=code_name.split(' ')
            name.append(company_name)
            company_code=company_code[1:-1]
            company_code='A'+company_code
            tickers.append(company_code)

            x = tag1[0]
            key_text = x.get("value")
            key_report_dir = key_text[0:14]
            #print(key_report_dir)
            new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/31155.htm'
            
            
            try:
                res=request.urlopen(new_url)
            except HTTPError as e:
                print(e)
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/71361.htm'
                res=request.urlopen(new_url)
            except HTTPError as e:
                print(e)
                
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/61361.htm'
                res=request.urlopen(new_url)
            except HTTPError as e:
                print(e)
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/70040.htm'
                res=request.urlopen(new_url)
            except HTTPError as e:
                print(e)
                
                
                
                
                
                
     
                
            soup=BeautifulSoup(res,'lxml')
            temps_ratio=soup.select_one('#XFormD1_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span').text
            if len(temps_ratio)<6:
                ratio=float(temps_ratio)
            else:
                temps_ratio=soup.select_one(' #XFormD1_Form0_Table0 > tbody > tr:nth-child(5) > td:nth-child(2) > span').text
                ratio=float(temps_ratio)
            ratio_list.append(ratio)

                #XFormD8_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span
# Out:
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\exp202207\Documents\Python Scripts\AWS_python\infra_invest\infra_crawler.ipynb Cell 3 in <cell line: 6>()
#      <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X14sZmlsZQ%3D%3D?line=56'>57</a>     print(e)
#      <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X14sZmlsZQ%3D%3D?line=65'>66</a> soup=BeautifulSoup(res,'lxml')
# ---> <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X14sZmlsZQ%3D%3D?line=66'>67</a> temps_ratio=soup.select_one('#XFormD1_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span').text
#      <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X14sZmlsZQ%3D%3D?line=67'>68</a> if len(temps_ratio)<6:
#      <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X14sZmlsZQ%3D%3D?line=68'>69</a>     ratio=float(temps_ratio)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df=pd.DataFrame(columns=['code','name','announce_date','total_ratio'])
tickers=list()
announce_date=list()
name=list()
ratio_list=list()       
if len(infra_dict2.keys()) !=0:
    for report_code in infra_dict2.keys():
        #if '정정' in reassess_dict[report_code][1]: 
        if '시설외' not in  infra_dict2[report_code][1]:
        
        
            announce_date.append(infra_dict2[report_code][0])
            new_url_temp= "https://kind.krx.co.kr/common/disclsviewer.do?method=search&acptno=" + report_code + "&docno=&viewerhost=&viewerport#viewer"
            res=request.urlopen(new_url_temp)
            soup = BeautifulSoup(res, "lxml")
            
            
            nth_options=str(soup.select('#mainDoc')[0]).count('</option>')
            tag1 = soup.select(f'#mainDoc > option:nth-of-type({nth_options})')
            code_name=soup.find('h1',attrs={'class':'ttl type-99 fleft'}).text ###이름 하고 기업 코드 추출
            
            company_name,company_code=code_name.split(' ')
            name.append(company_name)
            company_code=company_code[1:-1]
            company_code='A'+company_code
            tickers.append(company_code)

            x = tag1[0]
            key_text = x.get("value")
            key_report_dir = key_text[0:14]
            #print(key_report_dir)
            new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/31155.htm'
            
            
            try:
                res=request.urlopen(new_url)
            except HTTPError as e:
                print(e)
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/71361.htm'
                res=request.urlopen(new_url)
            except HTTPError as e:
                print(e)
                
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/61361.htm'
                res=request.urlopen(new_url)
            except HTTPError as e:
                print(e)
                
            try:
                new_url=f'https://kind.krx.co.kr/external/{report_code[:4]}/{report_code[4:6]}/{report_code[6:8]}/{report_code[8:14]}/{key_report_dir}/70040.htm'
                res=request.urlopen(new_url)
            except HTTPError as e:
                print(e)
                
                
            df=pd.read_html(new_url)
            df
# Out:
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# HTTP Error 404: Not Found
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\Users\exp202207\Documents\Python Scripts\AWS_python\infra_invest\infra_crawler.ipynb Cell 4 in <cell line: 6>()
#      <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X36sZmlsZQ%3D%3D?line=55'>56</a> except HTTPError as e:
#      <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X36sZmlsZQ%3D%3D?line=56'>57</a>     print(e)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X36sZmlsZQ%3D%3D?line=59'>60</a> df=pd.read_html(new_url)
#      <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X36sZmlsZQ%3D%3D?line=60'>61</a> df
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:919, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     916 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918 try:
# --> 919     tables = p.parse_tables()
#     920 except ValueError as caught:
#     921     # if `io` is an io-like object, check if it's seekable
#     922     # and try to rewind it before trying the next parser
#     923     if hasattr(io, "seekable") and io.seekable():
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:239, in _HtmlFrameParser.parse_tables(self)
#     231 def parse_tables(self):
#     232     """
#     233     Parse and return all tables from the DOM.
#     234
#    (...)
#     237     list of parsed (header, body, footer) tuples from tables.
#     238     """
# --> 239     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     240     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:758, in _LxmlFrameParser._build_doc(self)
#     756             pass
#     757     else:
# --> 758         raise e
#     759 else:
#     760     if not hasattr(r, "text_content"):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:739, in _LxmlFrameParser._build_doc(self)
#     737 try:
#     738     if is_url(self.io):
# --> 739         with urlopen(self.io) as f:
#     740             r = parse(f, parser=parser)
#     741     else:
#     742         # try to parse the input in the simplest way
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\common.py:236, in urlopen(*args, **kwargs)
#     230 """
#     231 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     232 the stdlib.
#     233 """
#     234 import urllib.request
# --> 236 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:555, in OpenerDirector.error(self, proto, *args)
#     553     http_err = 0
#     554 args = (dict, proto, meth_name) + args
# --> 555 result = self._call_chain(*args)
#     556 if result:
#     557     return result
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:747, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     744 fp.read()
#     745 fp.close()
# --> 747 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
new_url
# Out:
# 'https://kind.krx.co.kr/external/2022/12/23/000318/20221220001495/70040.htm'

# %%
pd.read_html(new_url)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# c:\Users\exp202207\Documents\Python Scripts\AWS_python\infra_invest\infra_crawler.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> pd.read_html(new_url)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:919, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     916 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918 try:
# --> 919     tables = p.parse_tables()
#     920 except ValueError as caught:
#     921     # if `io` is an io-like object, check if it's seekable
#     922     # and try to rewind it before trying the next parser
#     923     if hasattr(io, "seekable") and io.seekable():
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:239, in _HtmlFrameParser.parse_tables(self)
#     231 def parse_tables(self):
#     232     """
#     233     Parse and return all tables from the DOM.
#     234
#    (...)
#     237     list of parsed (header, body, footer) tuples from tables.
#     238     """
# --> 239     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     240     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:758, in _LxmlFrameParser._build_doc(self)
#     756             pass
#     757     else:
# --> 758         raise e
#     759 else:
#     760     if not hasattr(r, "text_content"):
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\html.py:739, in _LxmlFrameParser._build_doc(self)
#     737 try:
#     738     if is_url(self.io):
# --> 739         with urlopen(self.io) as f:
#     740             r = parse(f, parser=parser)
#     741     else:
#     742         # try to parse the input in the simplest way
#
# File ~\AppData\Roaming\Python\Python39\site-packages\pandas\io\common.py:236, in urlopen(*args, **kwargs)
#     230 """
#     231 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     232 the stdlib.
#     233 """
#     234 import urllib.request
# --> 236 return urllib.request.urlopen(*args, **kwargs)
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:214, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212 else:
#     213     opener = _opener
# --> 214 return opener.open(url, data, timeout)
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:555, in OpenerDirector.error(self, proto, *args)
#     553     http_err = 0
#     554 args = (dict, proto, meth_name) + args
# --> 555 result = self._call_chain(*args)
#     556 if result:
#     557     return result
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:747, in HTTPRedirectHandler.http_error_302(self, req, fp, code, msg, headers)
#     744 fp.read()
#     745 fp.close()
# --> 747 return self.parent.open(new, timeout=req.timeout)
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:523, in OpenerDirector.open(self, fullurl, data, timeout)
#     521 for processor in self.process_response.get(protocol, []):
#     522     meth = getattr(processor, meth_name)
# --> 523     response = meth(req, response)
#     525 return response
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:632, in HTTPErrorProcessor.http_response(self, request, response)
#     629 # According to RFC 2616, "2xx" code indicates that the client's
#     630 # request was successfully received, understood, and accepted.
#     631 if not (200 <= code < 300):
# --> 632     response = self.parent.error(
#     633         'http', request, response, code, msg, hdrs)
#     635 return response
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:561, in OpenerDirector.error(self, proto, *args)
#     559 if http_err:
#     560     args = (dict, 'default', 'http_error_default') + orig_args
# --> 561     return self._call_chain(*args)
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:494, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     492 for handler in handlers:
#     493     func = getattr(handler, meth_name)
# --> 494     result = func(*args)
#     495     if result is not None:
#     496         return result
#
# File c:\Users\exp202207\anaconda3\envs\quant\lib\urllib\request.py:641, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     640 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 641     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found

# %%
#XFormD1_Form0_Table0 > tbody > tr:nth-child(2) > td:nth-child(2) > span
#XFormD8_Form0_Table0 > tbody > tr:nth-child(2) > td:nth-child(2) > span

# %%
temps_ratio=soup.select_one('#XFormD1_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\exp202207\Documents\Python Scripts\AWS_python\infra_invest\infra_crawler.ipynb Cell 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> temps_ratio=soup.select_one('#XFormD1_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
#XFormD1_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span
#XFormD1_Form0_Table0 > tbody > tr:nth-child(5) > td:nth-child(2) > span

#XFormD8_Form0_Table0 > tbody > tr:nth-child(4) > td:nth-child(2) > span

# %%
temp_tag
# Out:
# '[정정]신규시설투자등'

# %%
'시설외' in infra_dict2[report_code][1]
# Out:
# True

# %%
ratio_list
# Out:
# [37.59, 11.5, 15.5, 11.28, 34.4, 31.24, 31.24, 17.6]

# %%
company_name
# Out:
# '바이넥스'

# %%
company_name
# Out:
# '휴온스'

# %%
new_url
# Out:
# 'https://kind.krx.co.kr/external/2022/11/28/000071/20221114000840/70040.htm'

# %%
infra_dict2[report_code]
# Out:
# ('2022-12-19', '신규시설투자등신세계건설')

# %%
soup.select_one('#XFormD1_Form0_Table0 > tbody > tr:nth-child(5) > td:nth-child(2) > span').text
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\exp202207\Documents\Python Scripts\AWS_python\infra_invest\infra_crawler.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> soup.select_one('#XFormD1_Form0_Table0 > tbody > tr:nth-child(5) > td:nth-child(2) > span').text
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
infra_dict2[report_code]
# Out:
# ('2022-09-28', '[정정]신규시설투자등(자회사의 주요경영사항)이녹스')

# %%
key_report_dir
# Out:
# '20220927001542'

# %%
convert_infra_dict[temp_infra]
# Out:
# '20221026000216'

# %%
new_url
# Out:
# 'https://kind.krx.co.kr/external/2022/09/28/000649/20220927001542/31155.htm'

# %%
company_name_data=driver.find_elements(By.XPATH,f'//*[@id="companysum"]')

# %%
num=842
spread=100
company_name_data=driver.find_elements(By.XPATH,f'//*[@id="companysum"]')
for i in range(1,spread+1):
    X_path_list=[]
    X_path_list.append(f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[4]/a')
    time.sleep(3)
    date=driver.find_element(By.XPATH,f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[2]').text
    date=date[:10]
    temp_company_name=company_name_data[i-1].text
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\exp202207\Documents\Python Scripts\AWS_python\infra_invest\infra_crawler.ipynb Cell 4 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> X_path_list=[]
#       <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> X_path_list.append(f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[4]/a')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a> time.sleep(3)
#       <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a> date=driver.find_element(By.XPATH,f'//*[@id="main-contents"]/section[1]/table/tbody/tr[{i}]/td[2]').text
#       <a href='vscode-notebook-cell:/c%3A/Users/exp202207/Documents/Python%20Scripts/AWS_python/infra_invest/infra_crawler.ipynb#W5sZmlsZQ%3D%3D?line=8'>9</a> date=date[:10]
#
# KeyboardInterrupt:

# %%
temp_company_name
# Out:
# 'SK디스커버리'

# %%
//*[@id="main-contents"]/section[1]/table/tbody/tr[1]/td[2]
//*[@id="main-contents"]/section[1]/table/tbody/tr[2]/td[2]
//*[@id="main-contents"]/section[1]/table/tbody/tr[100]/td[2]
